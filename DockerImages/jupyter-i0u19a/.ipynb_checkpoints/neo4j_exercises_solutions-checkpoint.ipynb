# %% [markdown]
# ### i0u19a - Data Processing - KU Leuven
#
# # Python Neo4j exercises
#
# ###### _Jan Aerts_
#
# ![license](https://licensebuttons.net/l/by/3.0/88x31.png)
#
# Hello and welcome to the tutorial on data processing with **Neo4j**!
# Before proceeding, make sure to have the neo4j server running as well, e.g with `docker run -d -p 7474:7474 jandot/neo4j-i0u19a`
#
# We'll be using Jupyter notebook again (you're looking at it) as a tool to walk you through a few examples. At the VDA-Lab, we like notebooks as a teaching tool because they allow you to experiment with code and data as you work your way through the document.
#
# A few guidelines on the notebook itself:
# * A notebook consists of *cells*, which are snippets of either text (markdown) or code (Python in this case).
# * Cells can be executed by clicking the `[>]` "play" button, or by hitting shift-enter on the keyboard.
# * You can navigate between cells either by clicking or by using the arrow buttons.

# %% [markdown]
# ### Neo4j documentation
#
# Check the general Neo4j documentation [here](http://neo4j.com/docs/stable/).
#
# py2neo API documentation: [http://py2neo.org/2.0/essentials.html](http://py2neo.org/2.0/essentials.html)

# %% [markdown]
# # The data
# The dataset consists of gene-gene and gene-disease interactions. Gene nodes have the type `:Gene`; disease nodes are of type `:Disease`. Gene-gene relationships are of type `:INTERACTS_WITH`; gene-disease relationships of type `:AFFECTS`.
#
# Node and relationship properties:
# * gene nodes: geneId, name
# * disease nodes: diseaseId, name
# * gene-gene relationships: nr_proofs, proofs
# * gene-disease relationships: score, associationType

# %% [markdown]
# # 1. Querying the data using the browser
# The neo4j database has a good web interface that you can use to look at the data. It can be reached on port 7474: [http://192.168.99.100:7474](http://192.168.99.100:7474) (as always: change the IP if necessary). It looks like this:
# ![screenshot_browser](images/screenshot_browser.png)
#
# Data can be queried using the CYPHER language. See [here](http://neo4j.com/developer/cypher-query-language/) for a tutorial. Some quick example queries:
#
# * Get 5 nodes: `MATCH (n) RETURN n LIMIT 5;`
# * Get number of nodes with 2 incoming links: `MATCH ()-->(m)<--() RETURN COUNT(m);`
#
# To get things working a bit faster, let's create some indexes on the name fields. Run the following commands in the browser query field:
# * `CREATE INDEX ON :Gene(name);`
# * `CREATE INDEX ON :Disease(name);`

# %% [markdown]
# ### Exercises
# * Fetch 3 diseases from the database.
# * What is the number of diseases in the database?
# * Find the number of paths between genes of length 2.
# * Which diseases are directly affected by the gene CRISP3?
# * What is the shortest path between the genes CRISP3 and ADAM22?
# * What are the 3 gene nodes with the highest degree?
# * Are there any gene-gene connections that might be due to indirect connections? In other words: which 2 genes are connected in 2 steps that are also connected in 1 step? That might mean that the direct connection is actually indirect.
# * Are there any cliques (= fully-connected subgraphs) of exactly 4 nodes? Return 1.

# %% [markdown]
# #### Solutions
# * `MATCH (n:Disease) RETURN n LIMIT 3;`
# * `MATCH (n:Disease) RETURN COUNT(n);`
# * `MATCH (n:Gene)-[r*2]->(m:Gene) WHERE NOT n = m RETURN COUNT(r);`
# * `MATCH (n:Gene {name: "CRISP3"})-[r]->(m:Disease) RETURN n,r,m;`
# * `MATCH p=shortestPath((n:Gene {name: 'CRISP3'})-[*..500]-(m:Gene {name: 'ADAM2'})) RETURN p;`
# * Solution:
# ```
# MATCH (n:Gene)-[r]-(m:Gene)
#   RETURN n.name, COUNT(r) AS DegreeScore
#   ORDER BY DegreeScore DESC
#   LIMIT 10;
# ```
# * `MATCH (n:Gene)-[r]->(m:Gene)-[s]->(o:Gene), (n:Gene)-[t]->(o:Gene) RETURN n,m,o,r,s,t LIMIT 2;`
# * `MATCH (a:Gene)--(b:Gene),(a)--(c:Gene),(a)--(d:Gene),(b)--(c),(b)--(d),(c)--(d) RETURN a,b,c,d LIMIT 1;`

# %% [markdown]
# # 2. Using the python API
# The CYPHER language as used above is very useful for extracting specific patterns from a graph database. However, if we want to investigate bigger structures, it is often necessary to go for a more generic approach. For example, if we want to find out more about the structure in the data.
#
# The python API for neo4j we use here is `py2neo`.
#
# ## 2.1 Connecting to the database
#
# To connect to the database from python, we will first need to:
# * Load the necessary modules
# * Create a graph_db connection
#
# The default user/password for neo4j is `neo4j/neo4j`, but the `jandot/neo4j-i0u19a` docker image is configured so that you don't need a username/password to access the data. This has been done by changing the neo4j configuration file:
#
# ```
# sed -i.bak 's/dbms.security.auth_enabled=true/dbms.security.auth_enabled=false/' /var/lib/neo4j/conf/neo4j-server.properties
# ```
#
# For a list of commands available for the py2neo API, see [here](http://py2neo.org/2.0/essentials.html).
#
# So let's connect.

# %%
from py2neo import Graph, Node, Relationship
graph_db = Graph("http://192.168.99.100:7474/db/data/") # Change IP if necessary

# %% [markdown]
# ## 2.2 Simple queries
# We can still use CYPHER as a language when working in py2neo:

# %%
graph_db.cypher.execute("MATCH (n:Gene)-[r]->(m:Gene)-[s]->(o:Disease) RETURN n.name,m.name,o.name LIMIT 5;")
# Out:
#    | n.name | m.name  | o.name
# ---+--------+---------+--------------------------
#  1 | IFIT3  | IFNA2   | Abdominal Pain
#  2 | APOB   | MTTP    | Abetalipoproteinemia
#  3 | ERBB3  | SLC31A1 | Congenital Abnormalities
#  4 | LGALS8 | SLC31A1 | Congenital Abnormalities
#  5 | NXF1   | SLC31A1 | Congenital Abnormalities

# %%
results = graph_db.cypher.execute("MATCH (n:Gene)-[r]->(m:Gene)-[s]->(o:Disease) RETURN n.name,m.name,o.name LIMIT 20;")
for result in results:
    print("Gene 1: ", result[0], "; Gene 2: ", result[2])
# Out:
# ('Gene 1: ', u'IFIT3', '; Gene 2: ', u'Abdominal Pain')
# ('Gene 1: ', u'APOB', '; Gene 2: ', u'Abetalipoproteinemia')
# ('Gene 1: ', u'ERBB3', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'LGALS8', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'NXF1', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'MOV10', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'CCS', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'SLC31A1', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'AURKA', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'CDH1', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'CTBP1', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'APP', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'CUL2', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'HDAC7', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'KAT5', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'EP300', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'HDAC1', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'HDAC2', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'HDAC5', '; Gene 2: ', u'Congenital Abnormalities')
# ('Gene 1: ', u'ELK1', '; Gene 2: ', u'Congenital Abnormalities')

# %%
abcd1 = graph_db.find_one("Gene", "name", "ABCD1")
print(abcd1.properties['name'])
# Out:
# ABCD1

# %% [markdown]
# What are the 10 disease nodes with the highest degree? Return the link-count and the node name.

# %%
results = graph_db.cypher.execute("MATCH (n:Disease)<-[r]-() RETURN n, count(r) ORDER BY count(r) DESC LIMIT 10;")
for result in results:
    print(result[1], result[0].properties['name'])
# Out:
# (460, u'Prostatic Neoplasms')
# (434, u'Glomerulonephritis; IGA')
# (402, u'Breast Neoplasms')
# (293, u'Peripheral Nervous System Diseases')
# (272, u'Stomach Neoplasms')
# (241, u'Autistic Disorder')
# (228, u'Colorectal Neoplasms')
# (214, u'Carcinoma; Hepatocellular')
# (193, u'Melanoma')
# (176, u'Schizophrenia')

# %% [markdown]
# ## 2.3 Does this look like a random network?
# Let's see how degree frequencies are distributed, and compare to a random network afterwards.
#
# To calculate degree frequencies:

# %%
results = graph_db.cypher.execute("MATCH (n:Gene)-[r]->(m:Gene) RETURN n, count(r);")
counts = {}
for result in results:
    if result[1] in counts:
        counts[result[1]] += 1
    else:
        counts[result[1]] = 1
counts
# Out:
# {1: 2252,
#  2: 1492,
#  3: 1036,
#  4: 795,
#  5: 660,
#  6: 594,
#  7: 506,
#  8: 442,
#  9: 401,
#  10: 320,
#  11: 312,
#  12: 274,
#  13: 263,
#  14: 234,
#  15: 204,
#  16: 218,
#  17: 172,
#  18: 165,
#  19: 140,
#  20: 137,
#  21: 125,
#  22: 126,
#  23: 117,
#  24: 96,
#  25: 102,
#  26: 126,
#  27: 72,
#  28: 95,
#  29: 66,
#  30: 74,
#  31: 55,
#  32: 72,
#  33: 56,
#  34: 60,
#  35: 51,
#  36: 63,
#  37: 39,
#  38: 50,
#  39: 44,
#  40: 36,
#  41: 48,
#  42: 38,
#  43: 29,
#  44: 37,
#  45: 25,
#  46: 34,
#  47: 28,
#  48: 33,
#  49: 27,
#  50: 29,
#  51: 24,
#  52: 27,
#  53: 24,
#  54: 25,
#  55: 18,
#  56: 13,
#  57: 19,
#  58: 21,
#  59: 28,
#  60: 22,
#  61: 15,
#  62: 16,
#  63: 14,
#  64: 16,
#  65: 12,
#  66: 15,
#  67: 10,
#  68: 18,
#  69: 14,
#  70: 12,
#  71: 14,
#  72: 7,
#  73: 15,
#  74: 14,
#  75: 8,
#  76: 10,
#  77: 5,
#  78: 13,
#  79: 5,
#  80: 4,
#  81: 5,
#  82: 11,
#  83: 6,
#  84: 7,
#  85: 9,
#  86: 8,
#  87: 6,
#  88: 8,
#  89: 3,
#  90: 11,
#  91: 9,
#  92: 1,
#  93: 4,
#  94: 6,
#  95: 6,
#  96: 4,
#  97: 1,
#  98: 3,
#  99: 3,
#  100: 4,
#  101: 5,
#  102: 2,
#  103: 9,
#  104: 3,
#  105: 5,
#  106: 2,
#  107: 4,
#  108: 6,
#  109: 3,
#  110: 8,
#  111: 1,
#  112: 2,
#  113: 5,
#  114: 6,
#  115: 4,
#  116: 1,
#  117: 4,
#  118: 1,
#  119: 3,
#  120: 4,
#  121: 6,
#  122: 4,
#  123: 2,
#  124: 3,
#  125: 5,
#  126: 3,
#  128: 2,
#  129: 1,
#  131: 4,
#  132: 3,
#  133: 1,
#  134: 1,
#  135: 4,
#  136: 1,
#  137: 1,
#  138: 1,
#  139: 1,
#  140: 4,
#  141: 4,
#  142: 1,
#  143: 2,
#  144: 2,
#  145: 2,
#  146: 2,
#  147: 1,
#  148: 2,
#  150: 1,
#  151: 2,
#  152: 3,
#  153: 1,
#  157: 3,
#  158: 1,
#  159: 1,
#  160: 1,
#  161: 1,
#  162: 2,
#  163: 2,
#  167: 2,
#  168: 1,
#  170: 1,
#  172: 3,
#  175: 2,
#  177: 1,
#  180: 1,
#  181: 3,
#  182: 1,
#  183: 1,
#  185: 3,
#  186: 2,
#  187: 1,
#  189: 1,
#  193: 1,
#  194: 1,
#  196: 1,
#  203: 2,
#  204: 1,
#  205: 1,
#  206: 2,
#  210: 1,
#  211: 2,
#  212: 1,
#  214: 2,
#  216: 1,
#  221: 2,
#  222: 1,
#  223: 1,
#  226: 1,
#  228: 1,
#  230: 1,
#  234: 2,
#  235: 1,
#  238: 2,
#  239: 1,
#  241: 1,
#  243: 1,
#  252: 1,
#  253: 3,
#  261: 1,
#  263: 2,
#  269: 1,
#  273: 1,
#  277: 1,
#  278: 1,
#  284: 1,
#  289: 1,
#  299: 2,
#  308: 1,
#  309: 1,
#  312: 1,
#  323: 1,
#  332: 1,
#  335: 1,
#  343: 1,
#  346: 1,
#  357: 1,
#  359: 1,
#  382: 1,
#  383: 1,
#  412: 1,
#  424: 1,
#  435: 1,
#  474: 1,
#  476: 1,
#  478: 1,
#  486: 1,
#  487: 1,
#  525: 1,
#  526: 1,
#  537: 1,
#  546: 1,
#  550: 1,
#  565: 1,
#  588: 1,
#  641: 1,
#  694: 1,
#  858: 1,
#  1006: 1,
#  1333: 1,
#  1951: 1}

# %% [markdown]
# Let's plot these using bokeh:

# %%
from bokeh.plotting import figure, show
from bokeh.charts import Bar
from bokeh.io import output_notebook
output_notebook()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-1e759564834d> in <module>()
# ----> 1 from bokeh.plotting import figure, show
#       2 from bokeh.charts import Bar
#       3 from bokeh.io import output_notebook
#       4 output_notebook()
#
# ImportError: No module named bokeh.plotting

# %%
a = list(counts.keys())
b = list(counts.values())
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')
p.line(a, b, legend="Temp.", line_width=2)
show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9f5db24f743e> in <module>()
#       1 a = list(counts.keys())
#       2 b = list(counts.values())
# ----> 3 p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')
#       4 p.line(a, b, legend="Temp.", line_width=2)
#       5 show(p)
#
# NameError: name 'figure' is not defined

# %% [markdown]
# Let's generate a new graph with the same fraction of nodes to relationships, connected at random. Ideally, we'd use the same number as in the real dataset, but that will take too long to generate... We'll take 1/10 of the size.
#
# Steps:
# 1. find out the number of gene nodes and the number of relationships
# 2. create new nodes and generate random relationships between them
# 3. recreate the same plot as above

# %% [markdown]
# #### 1. Get the number of gene nodes, and the number of relationships.

# %%
nr_nodes = graph_db.cypher.execute("MATCH (n:Gene) RETURN COUNT(n);")
print(nr_nodes[0][0])
nr_relationships = graph_db.cypher.execute("MATCH (n:Gene)-[r]->(m:Gene) RETURN COUNT(r);")
print(nr_relationships[0][0])
# Out:
# 61237
# 213340

# %% [markdown]
# #### 2. Create new nodes and random relationships
# Tips:
# * Give the nodes the label "RandomNode" so that you can easily filter them.
# * Creating these nodes and relationships might take a while. To know how far in the process you are, open a neo4j browser (i.e. http://192.168.99.100:7474), and execute either `MATCH (n:RandomNode) RETURN COUNT(n);` or `MATCH (n:RandomNode)-[r]->(m) RETURN COUNT(r);`.
# * Start with a **small** network first, to see if everything works as it should. For example, 1/100th of the real network. You can easily remove any tryouts with `MATCH (n:RandomNode) DETACH DELETE n;`.

# %%
n = graph_db.cypher.execute("MATCH (n:RandomNode) RETURN n LIMIT 1;")
if not n:
    scaling = 10
    nr_random_nodes = int(nr_nodes[0][0]/scaling)
    for i in range(1,nr_random_nodes):
        graph_db.create(Node("RandomNode", number=i))

    from random import randint
    for i in range(1,int(nr_relationships[0][0]/scaling)-1):
        n1 = randint(1,nr_random_nodes-1)
        n2 = randint(1,nr_random_nodes-1)
        node1 = graph_db.find_one("RandomNode","number",n1)
        node2 = graph_db.find_one("RandomNode","number",n2)
        graph_db.create(Relationship(node1, "LINKED_TO", node2))

# %% [markdown]
# #### 3. Now calculate everything and plot for these random data => are they the same?
# Calculate the same counts as above, and create the same plot. You do not have to load the bokeh library anymore, because we already did that.

# %%
random_results = graph_db.cypher.execute("MATCH (n:RandomNode)-[r]->(m:RandomNode) RETURN n, count(r);")
random_counts = {}
for result in random_results:
    if result[1] in random_counts:
        random_counts[result[1]] += 1
    else:
        random_counts[result[1]] = 1
random_counts
# Out:
# {1: 635,
#  2: 1144,
#  3: 1327,
#  4: 1187,
#  5: 774,
#  6: 463,
#  7: 214,
#  8: 114,
#  9: 46,
#  10: 14,
#  11: 4,
#  12: 2}

# %%
a = list(random_counts.keys())
b = list(random_counts.values())
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')
p.line(a, b, legend="Temp.", line_width=2)
show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7cb51c4b29de> in <module>()
#       1 a = list(random_counts.keys())
#       2 b = list(random_counts.values())
# ----> 3 p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')
#       4 p.line(a, b, legend="Temp.", line_width=2)
#       5 show(p)
#
# NameError: name 'figure' is not defined

# %% [markdown]
# ## 2.4 Centralities
# For many purposes, it is important to know how "central" a node is in a network. Of course, different definitions exist for centrality...
#
# ### A. Degree centrality
# Same as node degree: how many relationships does each node have?
#
# What are the 5 nodes with the highest degree centrality?

# %%
connected_nodes = graph_db.cypher.execute("MATCH (n:Gene)-[r]-(m:Gene) RETURN n, COUNT(r) ORDER BY COUNT(r) DESC LIMIT 5;")
connected_nodes
# Out:
#    | n                                             | COUNT(r)
# ---+-----------------------------------------------+----------
#  1 | (n1436:Gene {geneId:"APP",name:"APP"})        |     2058
#  2 | (n29813:Gene {geneId:"NTRK1",name:"NTRK1"})   |     1942
#  3 | (n17517:Gene {geneId:"ELAVL1",name:"ELAVL1"}) |     1762
#  4 | (n46572:Gene {geneId:"XPO1",name:"XPO1"})     |     1207
#  5 | (n14708:Gene {geneId:"CUL3",name:"CUL3"})     |     1189

# %% [markdown]
# So it seems that the gene APP has the highest number of relationships: 2,058. But wait a second... When we looked at the degree frequencies before, we found that the maximum frequency was 1,951. Why is this?
#
# Answer: previously, we looked at out-degree instead of in+out-degree. => should recalculate

# %% [markdown]
# ### B. Betweenness centrality
# How many critical paths go through this node? Calculate all shortest paths between all nodes, and check how many of these go through your node of interest. Unfortunately, this is a very compute intensive operation, so we'll create a small network of 15 nodes and 17 edges that looks like this:
# ![small network](images/small_network.png)

# %%
n = graph_db.cypher.execute("MATCH (n:NewNode) RETURN n LIMIT 1;")
links = [[0,1],[1,2],[1,3],[2,3],[2,4],[3,4],[4,5],[4,6],[6,7],[6,8],[8,9],[8,10],[8,11],[10,11],[4,12],[12,13],[12,14]]
if not n:
    newNodes = {}
    for i in range(0,15):
        newNodes[i] = Node("NewNode", number=i)
        graph_db.create(newNodes[i])
    for link in links:
        graph_db.create(Relationship(newNodes[link[0]], "CONNECTS_TO", newNodes[link[1]]))

# %% [markdown]
# Given this smaller dataset, let's calculate the betweenness centrality for each node.
#
# Tip: to calculate the shortest path between 2 nodes, use something like:
# ```
# MATCH p = shortestPath((a:NewNode {number: 0})-[*..500]-(b:NewNode {number: 14})) RETURN p
# ```

# %% [markdown]
# If we're going to run `shortestPath` queries, we need to find out what the output looks like exactly. So let's just calculate one, and dig in.

# %%
query = "MATCH p = shortestPath((a:NewNode {number: 3})-[*..500]-(b:NewNode {number: 11})) RETURN p"
result = graph_db.cypher.execute(query)
print("#### Result as a whole:")
print(result)
print("#### Getting the actual result without ID column:")
print(result[0])
print("#### Getting the path p:")
print(result[0].p)
print("#### What methods does this path object have?")
print(dir(result[0].p))
print("#### Getting the length of the path:")
print(result[0].p.size)
print("#### Getting a list of the nodes:")
print(result[0].p.nodes)
print("#### Getting the node IDs:")
print(list(map(lambda x: x.properties['number'], result[0].p.nodes)))
# Out:
# #### Result as a whole:
#    | p
# ---+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  1 | (:NewNode {number:3})-[:CONNECTS_TO]->(:NewNode {number:4})-[:CONNECTS_TO]->(:NewNode {number:6})-[:CONNECTS_TO]->(:NewNode {number:8})-[:CONNECTS_TO]->(:NewNode {number:11})
#
# #### Getting the actual result without ID column:
#  p
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  (:NewNode {number:3})-[:CONNECTS_TO]->(:NewNode {number:4})-[:CONNECTS_TO]->(:NewNode {number:6})-[:CONNECTS_TO]->(:NewNode {number:8})-[:CONNECTS_TO]->(:NewNode {number:11})
#
# #### Getting the path p:
# (:NewNode {number:3})-[:CONNECTS_TO]->(:NewNode {number:4})-[:CONNECTS_TO]->(:NewNode {number:6})-[:CONNECTS_TO]->(:NewNode {number:8})-[:CONNECTS_TO]->(:NewNode {number:11})
# #### What methods does this path object have?
# ['_Path__metadata', '_Path__nodes', '_Path__order', '_Path__relationships', '_Path__rels', '_Path__size', '__add__', '__bool__', '__class__', '__delattr__', '__dict__', '__doc__', '__eq__', '__format__', '__getattribute__', '__getitem__', '__hash__', '__init__', '__iter__', '__len__', '__module__', '__ne__', '__new__', '__nonzero__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', 'append', 'bound', 'create', 'end_node', 'exists', 'get_or_create', 'graph', 'hydrate', 'nodes', 'order', 'prepend', 'pull', 'push', 'relationships', 'rels', 'service_root', 'size', 'start_node', 'unbind']
# #### Getting the length of the path:
# 4
# #### Getting a list of the nodes:
# (<Node graph=u'http://192.168.99.100:7474/db/data/' ref=u'node/74123' labels=set([u'NewNode']) properties={u'number': 3}>, <Node graph=u'http://192.168.99.100:7474/db/data/' ref=u'node/74124' labels=set([u'NewNode']) properties={u'number': 4}>, <Node graph=u'http://192.168.99.100:7474/db/data/' ref=u'node/74126' labels=set([u'NewNode']) properties={u'number': 6}>, <Node graph=u'http://192.168.99.100:7474/db/data/' ref=u'node/74128' labels=set([u'NewNode']) properties={u'number': 8}>, <Node graph=u'http://192.168.99.100:7474/db/data/' ref=u'node/74131' labels=set([u'NewNode']) properties={u'number': 11}>)
# #### Getting the node IDs:
# [3, 4, 6, 8, 11]

# %% [markdown]
# Now let's count the actual number of times that each node is in the shortest path between any other two nodes.

# %%
template_query = "MATCH p = shortestPath((a:NewNode {number: X})-[*..500]-(b:NewNode {number: Y})) RETURN p"
node_counts = {}

## Initialize the counts to 0
for i in range(0,15):
    node_counts[i] = 0

## Fetch all shortest paths and count the number of times each node is mentioned
for i in range(0,15):
    for j in range(0,15):
        if i < j: # We don't want to fetch each shortest path twice (i.e. in both directions)
            query = template_query.replace('X',str(i)).replace('Y',str(j))
            r = graph_db.cypher.execute(query)            
            result = r[0].p
            for n in result.nodes:
                node_counts[n.properties['number']] += 1

node_counts
# Out:
# {0: 14,
#  1: 27,
#  2: 14,
#  3: 36,
#  4: 81,
#  5: 14,
#  6: 63,
#  7: 14,
#  8: 49,
#  9: 14,
#  10: 14,
#  11: 14,
#  12: 39,
#  13: 14,
#  14: 14}

# %% [markdown]
# ### C. Closeness centrality
# Is a bit less stringent than betweenness centrality: how much is a node in the "middle" of the network, not too far from the center? Calculate this by checking the average shortest path between this node and all other nodes.

# %%
template_query = "MATCH p = shortestPath((a:NewNode {number: X})-[*..500]-(b:NewNode {number: Y})) RETURN p"
path_lengths = {}
for i in range(0,15):
    path_lengths[i] = 0

for i in range(0,15):
    for j in range(0,15):
        if i < j:
            query = template_query.replace('X',str(i)).replace('Y',str(j))
            r = graph_db.cypher.execute(query)            
            result = r[0].p
            path_lengths[i] += r[0].p.size
            path_lengths[j] += r[0].p.size

path_lengths
# Out:
# {0: 58,
#  1: 45,
#  2: 35,
#  3: 35,
#  4: 27,
#  5: 40,
#  6: 30,
#  7: 43,
#  8: 37,
#  9: 50,
#  10: 49,
#  11: 49,
#  12: 36,
#  13: 49,
#  14: 49}

# %% [markdown]
# ## 2.4 Cliques
# Above, we identified cliques with 4 nodes. It'd be more useful to search for those containing 7 or more, as suggested in the paper by Pradhan et al [Cliques for the identification of gene signatures for colorectal cancer across population](http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3524317/). Unfortunately, this will give us a `java heapspace` error with the current setup of the server.
#
# So can we do this using the python API instead? One possible option might work like this:
# * Find all nodes that have a degree of 7.
# * For each of these, fetch the related nodes, and store these in a dictionary:
# ```
# {key: node_a, linked_nodes: [node_b, node_c, node_d, ...]}
# {key: node_b: linked_nodes: [node_a, node_c, node_d, ...]}
# ...
# ```
# * If we then take those arrays of linked nodes, add the key, and sort these, we will get something like this:
# ```
# [node_a, node_b, node_c, node_d, ...] # based on neighbours of node_a
# [node_a, node_b, node_c, node_d, ...] # based on neighbours of node_b
# ...
# ```
# * If a certain combination appears 7 times, we have a clique of 7.
#
# Of course, this is for nodes with **exactly** 7 relations. So for us find a clique of 7 like that, that clique would have to be unconnected from the rest of the graph. To correct for that, we actually need to search for those with *7 or more* relations, and instead of just checking for identity between the resulting arrays we have to check for subarrays.

# %%
## Plan of attack:
## * Get all nodes with 6 degrees
## * For each of these: fetch neighbours
## * Put those gene names in an array
## * Sort that array
## * If the same array appears 7 times: is clique of 7
nodes_with_6_degrees = graph_db.cypher.execute(
    "MATCH (n:Gene) \
     WITH n, size((n)--()) AS degree \
     WHERE degree = 6 \
     RETURN n")
node_names = map(lambda x:x[0].properties['name'], nodes_with_6_degrees)
for node_name in node_names:
    linked_nodes = graph_db.cypher.execute(''.join(["MATCH (n {name: '", node_name, "'})--(m:Gene) RETURN m"]))
    if len(linked_nodes) == 6:
        for ln in linked_nodes:
            print(' -- '.join([node_name, ln[0].properties['name']]))
# Out:
# ABTB1 -- EEF1D
# ABTB1 -- EEF1A2
# ABTB1 -- SMAD2
# ABTB1 -- SMAD9
# ABTB1 -- CUL3
# ABTB1 -- DNTTIP1
# ABTB2 -- XPO1
# ABTB2 -- COPS5
# ABTB2 -- DNTT
# ABTB2 -- RBX1
# ABTB2 -- CUL3
# ABTB2 -- EEF1A1
# ACAP1 -- RABGAP1L
# ACAP1 -- GRB2
# ACAP1 -- RAB11FIP3
# ACAP1 -- AKT1
# ACAP1 -- ITGB1
# ACAP1 -- IFFO1
# ACKR2 -- APP
# ACKR2 -- CCL14
# ACKR2 -- CCL13
# ACKR2 -- CCL7
# ACKR2 -- CCL5
# ACKR2 -- CCL8
# ACPP -- RPS6KB2
# ACPP -- DDX19B
# ACPP -- MMRN1
# ACPP -- SHBG
# ACPP -- UBC
# ACPP -- ACPP
# ADAMTSL3 -- NOTCH2NL
# ADAMTSL3 -- KRTAP10-3
# ADAMTSL3 -- KRTAP10-8
# ADAMTSL3 -- KRT40
# ADAMTSL3 -- KRTAP2-4
# ADAMTSL3 -- MDFI
# AGAP3 -- HERC2
# AGAP3 -- NTRK1
# AGAP3 -- HSPB1
# AGAP3 -- MIER2
# AGAP3 -- FKBP6
# AGAP3 -- YWHAB
# AHSP -- UBE3A
# AHSP -- FKBP1A
# AHSP -- TMEM165
# AHSP -- RAD21
# AHSP -- POLR2M
# AHSP -- ZC3H12A
# ALDH3B2 -- SLC18A1
# ALDH3B2 -- ZMYM2
# ALDH3B2 -- COX16
# ALDH3B2 -- ALDH3B1
# ALDH3B2 -- OBSL1
# ALDH3B2 -- CLGN
# ALG5 -- EDA
# ALG5 -- POMK
# ALG5 -- CACNG4
# ALG5 -- PKD2
# ALG5 -- CD1B
# ALG5 -- SPINT2
# ANXA13 -- CCDC67
# ANXA13 -- TUBGCP3
# ANXA13 -- ANXA2
# ANXA13 -- MSI2
# ANXA13 -- APBB1IP
# ANXA13 -- NEDD4
# ANXA8L1 -- RDH12
# ANXA8L1 -- ACD
# ANXA8L1 -- TINF2
# ANXA8L1 -- TERF2IP
# ANXA8L1 -- TERF1
# ANXA8L1 -- UCHL5
# ARHGAP12 -- XPO1
# ARHGAP12 -- TRIP10
# ARHGAP12 -- SRPK1
# ARHGAP12 -- SRPK2
# ARHGAP12 -- MAPK11
# ARHGAP12 -- GRB2
# ARHGAP15 -- APP
# ARHGAP15 -- KDM1A
# ARHGAP15 -- CD93
# ARHGAP15 -- PRNP
# ARHGAP15 -- SNCA
# ARHGAP15 -- RAC1
# ARHGEF18 -- CNTRL
# ARHGEF18 -- LTBR
# ARHGEF18 -- TERF1
# ARHGEF18 -- TAF10
# ARHGEF18 -- RHOA
# ARHGEF18 -- GNB1
# ARHGEF40 -- NTRK1
# ARHGEF40 -- SPERT
# ARHGEF40 -- LGR4
# ARHGEF40 -- APP
# ARHGEF40 -- STC2
# ARHGEF40 -- MYCBP
# ARL4A -- KRAS
# ARL4A -- CCDC57
# ARL4A -- SPATC1L
# ARL4A -- CCDC102B
# ARL4A -- GOLGA2
# ARL4A -- KPNA2
# ARL5A -- APP
# ARL5A -- ELAVL1
# ARL5A -- KPNA2
# ARL5A -- CBX3
# ARL5A -- CBX5
# ARL5A -- CBX1
# ATRN -- PTPRK
# ATRN -- BTNL8
# ATRN -- ZNF408
# ATRN -- XRN2
# ATRN -- FBXO6
# ATRN -- COPS5
# BCL2L10 -- CASP8
# BCL2L10 -- NR4A1
# BCL2L10 -- UBQLN1
# BCL2L10 -- BAX
# BCL2L10 -- BCL2
# BCL2L10 -- BCL2L10
# BLOC1S4 -- XPO1
# BLOC1S4 -- DTNBP1
# BLOC1S4 -- AIMP2
# BLOC1S4 -- BLOC1S2
# BLOC1S4 -- SNAPIN
# BLOC1S4 -- BLOC1S6
# BPHL -- MTHFD1L
# BPHL -- TTC19
# BPHL -- PPP5C
# BPHL -- SETD3
# BPHL -- MUT
# BPHL -- SHMT2
# BPNT1 -- MEMO1
# BPNT1 -- GDPGP1
# BPNT1 -- FAHD1
# BPNT1 -- TANGO2
# BPNT1 -- ACY1
# BPNT1 -- IQCB1
# BROX -- SORD
# BROX -- PDCD6IP
# BROX -- LDHA
# BROX -- HRSP12
# BROX -- FN1
# BROX -- CHMP4B
# C16orf87 -- HIST1H2BA
# C16orf87 -- MOV10
# C16orf87 -- MAGEA12
# C16orf87 -- HDAC2
# C16orf87 -- HDAC1
# C16orf87 -- ELAVL1
# C17orf53 -- LRRK2
# C17orf53 -- TRIM33
# C17orf53 -- XPO1
# C17orf53 -- PIK3R3
# C17orf53 -- PRMT1
# C17orf53 -- HECW2
# C17orf62 -- CREB3L1
# C17orf62 -- CREB3
# C17orf62 -- GTF2A1
# C17orf62 -- P2RX4
# C17orf62 -- CCDC155
# C17orf62 -- ETS1
# C19orf70 -- RAB5A
# C19orf70 -- HIF1A
# C19orf70 -- CLN3
# C19orf70 -- SLC25A3
# C19orf70 -- LAMTOR3
# C19orf70 -- MRPL24
# C1QTNF1 -- LNX1
# C1QTNF1 -- PRPF31
# C1QTNF1 -- UBQLN4
# C1QTNF1 -- CACNA1A
# C1QTNF1 -- AVPR2
# C1QTNF1 -- SGTA
# C1orf220 -- ATG4A
# C1orf220 -- NNT
# C1orf220 -- OXLD1
# C1orf220 -- NUDT15
# C1orf220 -- HCCS
# C1orf220 -- PDPR
# C20orf27 -- PPP1R3A
# C20orf27 -- PPP1CA
# C20orf27 -- PPP1CC
# C20orf27 -- TERF2
# C20orf27 -- RALYL
# C20orf27 -- PHKB
# C2orf47 -- MCM2
# C2orf47 -- TIMMDC1
# C2orf47 -- ABCE1
# C2orf47 -- HDAC11
# C2orf47 -- LYN
# C2orf47 -- APP
# C2orf69 -- KLC3
# C2orf69 -- TACC3
# C2orf69 -- VPS26A
# C2orf69 -- SORT1
# C2orf69 -- KIF11
# C2orf69 -- HDAC1
# C3orf33 -- KLHDC3
# C3orf33 -- SLC39A4
# C3orf33 -- PEX19
# C3orf33 -- BSG
# C3orf33 -- APP
# C3orf33 -- ELAVL1
# C4orf19 -- STK24
# C4orf19 -- STK26
# C4orf19 -- STK25
# C4orf19 -- EEF1A2
# C4orf19 -- PDCD10
# C4orf19 -- EIF3E
# C4orf3 -- CALM1
# C4orf3 -- ERMP1
# C4orf3 -- DEGS1
# C4orf3 -- EDC4
# C4orf3 -- PANX1
# C4orf3 -- GCN1L1
# C4orf46 -- KXD1
# C4orf46 -- TFPT
# C4orf46 -- CDR2
# C4orf46 -- SRPK2
# C4orf46 -- APP
# C4orf46 -- ELAVL1
# C5orf24 -- FOXC2
# C5orf24 -- FOXC1
# C5orf24 -- CREB1
# C5orf24 -- MMGT1
# C5orf24 -- PCDHB15
# C5orf24 -- EFEMP2
# C5orf60 -- NOTCH2NL
# C5orf60 -- KRTAP10-9
# C5orf60 -- KRT40
# C5orf60 -- KRTAP3-2
# C5orf60 -- GMCL1
# C5orf60 -- KRT31
# C6orf106 -- XPO1
# C6orf106 -- MAP3K1
# C6orf106 -- RPSA
# C6orf106 -- FBXO25
# C6orf106 -- APP
# C6orf106 -- ELAVL1
# CABLES2 -- DLK1
# CABLES2 -- FIBP
# CABLES2 -- ABL1
# CABLES2 -- CDK5
# CABLES2 -- CDK3
# CABLES2 -- TP53
# CAMTA2 -- PSME3
# CAMTA2 -- FAM192A
# CAMTA2 -- CALM3
# CAMTA2 -- CALM2
# CAMTA2 -- HDAC5
# CAMTA2 -- NKX2-5
# CAPN11 -- SKIV2L2
# CAPN11 -- PRODH
# CAPN11 -- UNG
# CAPN11 -- PRKAR1A
# CAPN11 -- XRCC6
# CAPN11 -- ANAPC11
# CAPRIN2 -- FAM8A1
# CAPRIN2 -- AUP1
# CAPRIN2 -- PEX5
# CAPRIN2 -- LRP6
# CAPRIN2 -- LRP5
# CAPRIN2 -- COPS6
# CARS2 -- CAPN1
# CARS2 -- PTEN
# CARS2 -- BLM
# CARS2 -- OXLD1
# CARS2 -- RGCC
# CARS2 -- EGFR
# CCDC113 -- LTBR
# CCDC113 -- SMYD1
# CCDC113 -- PFN2
# CCDC113 -- IMMT
# CCDC113 -- HAP1
# CCDC113 -- GIT1
# CCDC153 -- DTNBP1
# CCDC153 -- NECAB2
# CCDC153 -- GORASP2
# CCDC153 -- NUP62
# CCDC153 -- DDIT3
# CCDC153 -- CDR2
# CCNI2 -- CDK5
# CCNI2 -- LARP1B
# CCNI2 -- HSPA1L
# CCNI2 -- HSPA6
# CCNI2 -- HSPA8
# CCNI2 -- HSPA1B
# CD72 -- CD5
# CD72 -- BLNK
# CD72 -- SYK
# CD72 -- LYN
# CD72 -- PTPN6
# CD72 -- SEMA4D
# CDK5RAP1 -- C9orf41
# CDK5RAP1 -- KCTD17
# CDK5RAP1 -- EXOSC5
# CDK5RAP1 -- EXOSC3
# CDK5RAP1 -- BAG3
# CDK5RAP1 -- CDK5R1
# CDKL2 -- CDC37
# CDKL2 -- HSP90AA4P
# CDKL2 -- HSP90AA5P
# CDKL2 -- HSP90AA1
# CDKL2 -- FRY
# CDKL2 -- APP
# CDX4 -- PRKAA1
# CDX4 -- LMO2
# CDX4 -- LMO1
# CDX4 -- CKS1B
# CDX4 -- PRKAB2
# CDX4 -- PITX1
# CFAP20 -- FOXJ1
# CFAP20 -- XPO1
# CFAP20 -- BMI1
# CFAP20 -- TFCP2L1
# CFAP20 -- SF3A2
# CFAP20 -- YWHAG
# CHID1 -- TCTN1
# CHID1 -- MAN2B1
# CHID1 -- GAA
# CHID1 -- PAFAH1B1
# CHID1 -- TMEM25
# CHID1 -- APP
# CLEC4M -- GRN
# CLEC4M -- TLR2
# CLEC4M -- MME
# CLEC4M -- CD209
# CLEC4M -- CLEC4M
# CLEC4M -- AP2M1
# CLIP2 -- KLC4
# CLIP2 -- MAPRE1
# CLIP2 -- ITSN1
# CLIP2 -- MAX
# CLIP2 -- CLASP2
# CLIP2 -- CLASP1
# CMTM3 -- MOB3C
# CMTM3 -- MOB1A
# CMTM3 -- APP
# CMTM3 -- SPP1
# CMTM3 -- MEST
# CMTM3 -- RABAC1
# CNTLN -- PRSS12
# CNTLN -- C9orf41
# CNTLN -- TPM1
# CNTLN -- HDAC6
# CNTLN -- BRCA1
# CNTLN -- SP1
# CNTNAP4 -- RANBP10
# CNTNAP4 -- MACF1
# CNTNAP4 -- FBXO21
# CNTNAP4 -- MAST3
# CNTNAP4 -- APBA1
# CNTNAP4 -- CASK
# COX16 -- NYX
# COX16 -- ERGIC3
# COX16 -- KPTN
# COX16 -- ALDH3B2
# COX16 -- FAS
# COX16 -- FCGR3B
# CRIPAK -- PAXIP1
# CRIPAK -- ECT2
# CRIPAK -- BRCA1
# CRIPAK -- BARD1
# CRIPAK -- ESR1
# CRIPAK -- PAK1
# CST9L -- NOTCH2NL
# CST9L -- KRTAP10-3
# CST9L -- KRTAP10-9
# CST9L -- CCR5
# CST9L -- TAB2
# CST9L -- SLC22A2
# DALRD3 -- ATL3
# DALRD3 -- ZDHHC17
# DALRD3 -- HNRNPK
# DALRD3 -- BRCA1
# DALRD3 -- TK1
# DALRD3 -- CSNK2B
# DCAF12 -- DDA1
# DCAF12 -- COPS6
# DCAF12 -- COPS5
# DCAF12 -- ELAVL1
# DCAF12 -- CUL4A
# DCAF12 -- DDB1
# DCAF4L2 -- CUL4A
# DCAF4L2 -- CUL4B
# DCAF4L2 -- PYGL
# DCAF4L2 -- CCT6B
# DCAF4L2 -- CLUH
# DCAF4L2 -- COPS2
# DCLRE1A -- YWHAH
# DCLRE1A -- UBC
# DCLRE1A -- PCNA
# DCLRE1A -- PIAS1
# DCLRE1A -- ATM
# DCLRE1A -- TP53BP1
# DDX49 -- HIST1H2BG
# DDX49 -- APP
# DDX49 -- NSUN2
# DDX49 -- PSMB2
# DDX49 -- PNO1
# DDX49 -- HAP1
# DGKD -- SREK1
# DGKD -- TNFRSF14
# DGKD -- DGKD
# DGKD -- IGSF21
# DGKD -- HAX1
# DGKD -- DGKH
# DHRS4L2 -- D2HGDH
# DHRS4L2 -- ACOT7
# DHRS4L2 -- ZZEF1
# DHRS4L2 -- DHRS4
# DHRS4L2 -- AARS2
# DHRS4L2 -- MTIF2
# DHX34 -- KIF3A
# DHX34 -- EXOC8
# DHX34 -- TRMT2A
# DHX34 -- RPS6KA6
# DHX34 -- GSK3B
# DHX34 -- POLA2
# DNAJC14 -- CPVL
# DNAJC14 -- SARNP
# DNAJC14 -- IGSF8
# DNAJC14 -- ELAVL1
# DNAJC14 -- DRD1
# DNAJC14 -- LYST
# DNAJC16 -- TCTN3
# DNAJC16 -- TCTN2
# DNAJC16 -- BTNL8
# DNAJC16 -- HLA-C
# DNAJC16 -- TMEM30A
# DNAJC16 -- SPINT2
# DPY19L4 -- ZACN
# DPY19L4 -- MCOLN3
# DPY19L4 -- NXF1
# DPY19L4 -- CUL5
# DPY19L4 -- CUL4B
# DPY19L4 -- ELAVL1
# DUSP4 -- MAPK9
# DUSP4 -- APP
# DUSP4 -- CRMP1
# DUSP4 -- MAPK8
# DUSP4 -- MAPK14
# DUSP4 -- MAPK3
# E2F5 -- TFDP2
# E2F5 -- KMT2D
# E2F5 -- BRCC3
# E2F5 -- RBL1
# E2F5 -- RBL2
# E2F5 -- TFDP1
# EFNA3 -- NOTCH2NL
# EFNA3 -- KRTAP10-3
# EFNA3 -- MEOX2
# EFNA3 -- EPHA3
# EFNA3 -- EPHA7
# EFNA3 -- PRSS23
# ELMOD1 -- DSG4
# ELMOD1 -- LGALS3
# ELMOD1 -- PKP3
# ELMOD1 -- LRRC15
# ELMOD1 -- SELENBP1
# ELMOD1 -- THG1L
# ELSPBP1 -- PSMD9
# ELSPBP1 -- TAL1
# ELSPBP1 -- ELSPBP1
# ELSPBP1 -- TWIST1
# ELSPBP1 -- EP300
# ELSPBP1 -- MYOD1
# EMID1 -- KRAS
# EMID1 -- YTHDF1
# EMID1 -- COLGALT2
# EMID1 -- UBR4
# EMID1 -- KLHL25
# EMID1 -- CDC5L
# ENPP4 -- KRAS
# ENPP4 -- LPAR1
# ENPP4 -- LGALS9
# ENPP4 -- SOX2
# ENPP4 -- LGALS8
# ENPP4 -- LGALS3
# ESRP2 -- FOXP3
# ESRP2 -- VPS16
# ESRP2 -- RPA1
# ESRP2 -- RPA2
# ESRP2 -- RPA3
# ESRP2 -- NUMBL
# ETV7 -- PDLIM7
# ETV7 -- ETV6
# ETV7 -- VTN
# ETV7 -- LRPAP1
# ETV7 -- IRF4
# ETV7 -- L3MBTL1
# EXD2 -- HERC2
# EXD2 -- NTRK1
# EXD2 -- GRAMD3
# EXD2 -- DCTN2
# EXD2 -- PEX19
# EXD2 -- CCDC8
# FAM120C -- SEC16A
# FAM120C -- HNRNPU
# FAM120C -- TFCP2
# FAM120C -- HNRNPA1
# FAM120C -- BANP
# FAM120C -- ISG15
# FAM133B -- PPP4R2
# FAM133B -- TSNAX
# FAM133B -- CDK2
# FAM133B -- ATR
# FAM133B -- HECW2
# FAM133B -- APP
# FAM13B -- UNK
# FAM13B -- SAMHD1
# FAM13B -- ELAVL1
# FAM13B -- YWHAZ
# FAM13B -- YWHAE
# FAM13B -- YWHAG
# FAM153B -- TYW5
# FAM153B -- EDC4
# FAM153B -- EIF2AK4
# FAM153B -- EHD1
# FAM153B -- UBB
# FAM153B -- FAM153A
# FAM160B2 -- CLK1
# FAM160B2 -- SMG8
# FAM160B2 -- ZNF318
# FAM160B2 -- RECQL4
# FAM160B2 -- DYNC2H1
# FAM160B2 -- APP
# FAM213B -- PROCR
# FAM213B -- NARS
# FAM213B -- HRAS
# FAM213B -- NUCB1
# FAM213B -- PDPK1
# FAM213B -- TNFSF11
# FAM45A -- RNF168
# FAM45A -- KBTBD7
# FAM45A -- CCDC22
# FAM45A -- CCDC93
# FAM45A -- COMMD4
# FAM45A -- COMMD3
# FASTKD1 -- SCN2B
# FASTKD1 -- ARL13B
# FASTKD1 -- LPAR6
# FASTKD1 -- SPDEF
# FASTKD1 -- KIR2DS2
# FASTKD1 -- BSG
# FAXC -- MSN
# FAXC -- ESD
# FAXC -- ALDH6A1
# FAXC -- CCT8
# FAXC -- ACADM
# FAXC -- FAXC
# FBRSL1 -- XPO1
# FBRSL1 -- CSNK2A2
# FBRSL1 -- RYBP
# FBRSL1 -- RNF2
# FBRSL1 -- PCGF5
# FBRSL1 -- PCGF3
# FBXL14 -- DICER1
# FBXL14 -- HSP90AA1
# FBXL14 -- COPS6
# FBXL14 -- COPS5
# FBXL14 -- CUL1
# FBXL14 -- SNAI1
# FBXL16 -- PPP2R2A
# FBXL16 -- PPP2R1A
# FBXL16 -- MARK2
# FBXL16 -- LATS2
# FBXL16 -- HPCAL4
# FBXL16 -- MAPK6
# FBXO15 -- CPA6
# FBXO15 -- HINT3
# FBXO15 -- OS9
# FBXO15 -- CRLS1
# FBXO15 -- UBA7
# FBXO15 -- ABCB1
# FLYWCH1 -- NFATC1
# FLYWCH1 -- KIF11
# FLYWCH1 -- HTATSF1
# FLYWCH1 -- BRCA1
# FLYWCH1 -- ELAVL1
# FLYWCH1 -- SETDB1
# FMNL3 -- NTRK1
# FMNL3 -- CIAO1
# FMNL3 -- FAM96B
# FMNL3 -- MMS19
# FMNL3 -- APP
# FMNL3 -- PRPF40A
# FRMD8 -- FRMD8P1
# FRMD8 -- PLEKHF2
# FRMD8 -- GRAMD3
# FRMD8 -- APP
# FRMD8 -- ELAVL1
# FRMD8 -- IKBKG
# GAB3 -- ABL1
# GAB3 -- GRB2
# GAB3 -- LYN
# GAB3 -- FYN
# GAB3 -- SRC
# GAB3 -- PTPN11
# GABPB2 -- PLCG2
# GABPB2 -- CRK
# GABPB2 -- ZDHHC17
# GABPB2 -- GORASP2
# GABPB2 -- KDM1A
# GABPB2 -- RYBP
# GALNT18 -- PTPRK
# GALNT18 -- TMEM25
# GALNT18 -- PLAUR
# GALNT18 -- IDS
# GALNT18 -- TAZ
# GALNT18 -- CEP250
# GAREM -- XPO1
# GAREM -- CRK
# GAREM -- NTRK1
# GAREM -- GRAP2
# GAREM -- CRKL
# GAREM -- GRB2
# GAS8 -- LRP6
# GAS8 -- HEATR6
# GAS8 -- IQCB1
# GAS8 -- TP73
# GAS8 -- TP63
# GAS8 -- CIAO1
# GATSL3 -- WDR59
# GATSL3 -- WDR24
# GATSL3 -- MIOS
# GATSL3 -- GATSL2
# GATSL3 -- GATSL3
# GATSL3 -- ZC2HC1A
# GDPD5 -- LYPD3
# GDPD5 -- KRTAP26-1
# GDPD5 -- TRIP6
# GDPD5 -- SIAH1
# GDPD5 -- PEX5
# GDPD5 -- PLSCR1
# GLRX2 -- PITPNB
# GLRX2 -- MDH2
# GLRX2 -- GPX4
# GLRX2 -- CYCS
# GLRX2 -- BAG3
# GLRX2 -- TXNRD1
# GLTSCR1L -- RAB5C
# GLTSCR1L -- SMARCD1
# GLTSCR1L -- ELAVL1
# GLTSCR1L -- DTNBP1
# GLTSCR1L -- CDC5L
# GLTSCR1L -- NFYC
# GNGT2 -- SRPK2
# GNGT2 -- GNB3
# GNGT2 -- GNB1
# GNGT2 -- GNB4
# GNGT2 -- GNB2
# GNGT2 -- KCNJ4
# GPBP1 -- SORT1
# GPBP1 -- HNRNPD
# GPBP1 -- PLEKHF2
# GPBP1 -- C20orf195
# GPBP1 -- DNAL4
# GPBP1 -- MCRS1
# GPC1 -- PTEN
# GPC1 -- GPR183
# GPC1 -- FGF1
# GPC1 -- PFDN5
# GPC1 -- SLIT2
# GPC1 -- VEGFA
# GPR137B -- NCAPG
# GPR137B -- DOC2A
# GPR137B -- NCAPH
# GPR137B -- ZYG11B
# GPR137B -- SMC2
# GPR137B -- NCAPD2
# GPRIN1 -- ZNF281
# GPRIN1 -- YEATS4
# GPRIN1 -- HNRNPD
# GPRIN1 -- NTRK1
# GPRIN1 -- TMEM185A
# GPRIN1 -- SDF4
# GRAMD1C -- APP
# GRAMD1C -- SCARA3
# GRAMD1C -- EVA1C
# GRAMD1C -- GRAMD3
# GRAMD1C -- FIBP
# GRAMD1C -- CD151
# GRIP2 -- KRAS
# GRIP2 -- GFI1B
# GRIP2 -- GIT1
# GRIP2 -- ERC2
# GRIP2 -- PPFIA1
# GRIP2 -- CSPG4
# GSDMA -- MCM2
# GSDMA -- FOXH1
# GSDMA -- CEP152
# GSDMA -- IFI16
# GSDMA -- SUZ12
# GSDMA -- PARK2
# GTF2H2C -- XPO1
# GTF2H2C -- GTF2H4
# GTF2H2C -- GTF2H3
# GTF2H2C -- GTF2H1
# GTF2H2C -- ERCC3
# GTF2H2C -- GTF2H2C_2
# GUCY1B3 -- LIN7A
# GUCY1B3 -- APP
# GUCY1B3 -- STUB1
# GUCY1B3 -- GUCY1A2
# GUCY1B3 -- HSP90AA1
# GUCY1B3 -- NOS3
# HEBP1 -- UBE2L3
# HEBP1 -- SNX3
# HEBP1 -- S100A6
# HEBP1 -- PCBP1
# HEBP1 -- COTL1
# HEBP1 -- DHX36
# HELZ2 -- IFI16
# HELZ2 -- BMI1
# HELZ2 -- ISG15
# HELZ2 -- SIRT7
# HELZ2 -- BCL6
# HELZ2 -- PPARA
# HES4 -- SHMT2
# HES4 -- COPG2
# HES4 -- RGS3
# HES4 -- LTN1
# HES4 -- PCBD2
# HES4 -- PCBD1
# HID1 -- CSDE1
# HID1 -- INPPL1
# HID1 -- RCN3
# HID1 -- CBS
# HID1 -- RBBP8
# HID1 -- BEGAIN
# HIST1H3F -- MCM2
# HIST1H3F -- ITGA4
# HIST1H3F -- TRIM24
# HIST1H3F -- HDGF
# HIST1H3F -- PHF1
# HIST1H3F -- ASF1B
# HIST1H3G -- MCM2
# HIST1H3G -- ITGA4
# HIST1H3G -- TRIM24
# HIST1H3G -- HDGF
# HIST1H3G -- PHF1
# HIST1H3G -- NASP
# HIST2H2AA4 -- MCM2
# HIST2H2AA4 -- HIST1H3A
# HIST2H2AA4 -- HIST1H2BG
# HIST2H2AA4 -- OBSL1
# HIST2H2AA4 -- CUL7
# HIST2H2AA4 -- CHD1L
# HLA-DQB2 -- PRL
# HLA-DQB2 -- ERAP1
# HLA-DQB2 -- TRMT44
# HLA-DQB2 -- COL14A1
# HLA-DQB2 -- ATE1
# HLA-DQB2 -- OAF
# HMGN5 -- ZC3H15
# HMGN5 -- RRP9
# HMGN5 -- HSPB1
# HMGN5 -- C11orf58
# HMGN5 -- BASP1
# HMGN5 -- CBX8
# HMGXB3 -- PFDN1
# HMGXB3 -- ANXA7
# HMGXB3 -- SMN1
# HMGXB3 -- CDK4
# HMGXB3 -- CDKN1A
# HMGXB3 -- TK1
# HOXC10 -- ESR1
# HOXC10 -- NXF1
# HOXC10 -- EGFR
# HOXC10 -- NUP205
# HOXC10 -- YWHAG
# HOXC10 -- CWC27
# HRASLS5 -- CLK1
# HRASLS5 -- VCPIP1
# HRASLS5 -- LOC155060
# HRASLS5 -- GGACT
# HRASLS5 -- GOLGA2
# HRASLS5 -- APP
# HRK -- ELAVL1
# HRK -- BCL2L1
# HRK -- BCL2A1
# HRK -- MCL1
# HRK -- BCL2L2
# HRK -- BCL2
# HS1BP3 -- CEP170
# HS1BP3 -- NAA38
# HS1BP3 -- RWDD2B
# HS1BP3 -- TMED3
# HS1BP3 -- ZDHHC17
# HS1BP3 -- VCP
# HSPBAP1 -- FOXD4L6
# HSPBAP1 -- MAGEA1
# HSPBAP1 -- NUTM1
# HSPBAP1 -- ARHGEF5
# HSPBAP1 -- TK1
# HSPBAP1 -- PTN
# HTR3E -- ARL6IP5
# HTR3E -- CYP51A1
# HTR3E -- AMFR
# HTR3E -- DHRS7
# HTR3E -- GET4
# HTR3E -- ATP2A3
# IKZF5 -- IKZF3
# IKZF5 -- IKZF1
# IKZF5 -- IKZF4
# IKZF5 -- IKZF5
# IKZF5 -- LDOC1
# IKZF5 -- CCDC85B
# IL37 -- GSG1
# IL37 -- FADD
# IL37 -- IL37
# IL37 -- IL18R1
# IL37 -- CASP4
# IL37 -- CASP1
# INHBB -- ACVR1C
# INHBB -- FNTA
# INHBB -- IGSF1
# INHBB -- ACVR1B
# INHBB -- ACVR2B
# INHBB -- ACVR2A
# INPP5J -- TRIM54
# INPP5J -- DNAJA3
# INPP5J -- CDC23
# INPP5J -- TRIM27
# INPP5J -- GOLGA2
# INPP5J -- EPS8
# IRGQ -- ZSCAN26
# IRGQ -- PLK2
# IRGQ -- NTRK1
# IRGQ -- XPNPEP1
# IRGQ -- NFYA
# IRGQ -- GABARAPL2
# ITFG2 -- HSPB9
# ITFG2 -- INPP5A
# ITFG2 -- BTN2A1
# ITFG2 -- SNX24
# ITFG2 -- C1QTNF2
# ITFG2 -- KPTN
# ITM2C -- TMEM216
# ITM2C -- TMEM17
# ITM2C -- MVB12B
# ITM2C -- CUL7
# ITM2C -- RYK
# ITM2C -- RNF7
# ITPRIP -- HTR3C
# ITPRIP -- PLTP
# ITPRIP -- ATP1B4
# ITPRIP -- RASSF1
# ITPRIP -- CD1B
# ITPRIP -- FBXO6
# ITPRIPL1 -- GPR183
# ITPRIPL1 -- SPINT2
# ITPRIPL1 -- CD3E
# ITPRIPL1 -- UBQLN1
# ITPRIPL1 -- SGTA
# ITPRIPL1 -- UBQLN4
# JMY -- MYO1C
# JMY -- MYH9
# JMY -- PPP1R1A
# JMY -- VAPB
# JMY -- CCDC136
# JMY -- EP300
# KDELR3 -- MCM2
# KDELR3 -- DPEP2
# KDELR3 -- VSIG4
# KDELR3 -- LPAR6
# KDELR3 -- SLC39A4
# KDELR3 -- TMEM171
# KDM4D -- HECW2
# KDM4D -- PPP1CC
# KDM4D -- CUL4B
# KDM4D -- TP53
# KDM4D -- AR
# KDM4D -- KDM4D
# KIAA0430 -- DCP1A
# KIAA0430 -- GTSE1
# KIAA0430 -- CRKL
# KIAA0430 -- CLTC
# KIAA0430 -- ELAVL1
# KIAA0430 -- TERF2
# KIAA1161 -- SIAE
# KIAA1161 -- PTCH1
# KIAA1161 -- DLK1
# KIAA1161 -- ATP1B4
# KIAA1161 -- LYPD3
# KIAA1161 -- FBXO6
# KIAA1328 -- CCDC14
# KIAA1328 -- FGFR1OP
# KIAA1328 -- CEP135
# KIAA1328 -- OFD1
# KIAA1328 -- PCM1
# KIAA1328 -- APC
# KIF24 -- TSNAX
# KIF24 -- RPS19BP1
# KIF24 -- DOT1L
# KIF24 -- CEP97
# KIF24 -- JAK1
# KIF24 -- PRKAA2
# KLRF1 -- TP53
# KLRF1 -- REEP6
# KLRF1 -- CBWD1
# KLRF1 -- REEP5
# KLRF1 -- TOMM40
# KLRF1 -- GAPDHS
# KRBA1 -- PRMT2
# KRBA1 -- RFPL4B
# KRBA1 -- KLHL20
# KRBA1 -- PLK1
# KRBA1 -- GSK3B
# KRBA1 -- GSK3A
# KRT34 -- HNRNPA1
# KRT34 -- EPS15
# KRT34 -- GRB2
# KRT34 -- USP15
# KRT34 -- DLG3
# KRT34 -- PLEKHB2
# KRT72 -- MYO19
# KRT72 -- TRRAP
# KRT72 -- HSPB1
# KRT72 -- KRT40
# KRT72 -- KRT18
# KRT72 -- KRT17
# LAX1 -- CREB1
# LAX1 -- STAMBPL1
# LAX1 -- GRB7
# LAX1 -- NDN
# LAX1 -- GRAP2
# LAX1 -- GRB2
# LCN1 -- NTRK1
# LCN1 -- PDYN
# LCN1 -- PECR
# LCN1 -- WWOX
# LCN1 -- LMBR1L
# LCN1 -- KHK
# LCN15 -- ATG4A
# LCN15 -- SETX
# LCN15 -- NUDT15
# LCN15 -- DIS3L
# LCN15 -- ALKBH2
# LCN15 -- MYO9B
# LIX1L -- TRIM25
# LIX1L -- GGA1
# LIX1L -- EIF4H
# LIX1L -- CAPNS2
# LIX1L -- NXF1
# LIX1L -- MOV10
# LOC155060 -- NXF1
# LOC155060 -- SHMT2
# LOC155060 -- LOC155060
# LOC155060 -- HRASLS5
# LOC155060 -- ZNF398
# LOC155060 -- ZNF212
# LOH12CR1 -- BCAS4
# LOH12CR1 -- C17orf59
# LOH12CR1 -- FGL1
# LOH12CR1 -- TEX35
# LOH12CR1 -- FBXO25
# LOH12CR1 -- PUF60
# LY6G5B -- TUBGCP3
# LY6G5B -- TP53
# LY6G5B -- NEDD1
# LY6G5B -- CEP57
# LY6G5B -- VCAM1
# LY6G5B -- FN1
# LYG2 -- PYHIN1
# LYG2 -- APIP
# LYG2 -- SGOL2
# LYG2 -- DOLPP1
# LYG2 -- RAB11B
# LYG2 -- TEX35
# MAGEB1 -- SRPK1
# MAGEB1 -- SRPK2
# MAGEB1 -- EID2
# MAGEB1 -- EID3
# MAGEB1 -- NSMCE4A
# MAGEB1 -- NEDD4L
# MAML2 -- RBPJ
# MAML2 -- EP300
# MAML2 -- CREBBP
# MAML2 -- DIABLO
# MAML2 -- NOTCH1
# MAML2 -- MAML1
# MAP3K7CL -- AK8
# MAP3K7CL -- REL
# MAP3K7CL -- KRT31
# MAP3K7CL -- CISH
# MAP3K7CL -- GPS2
# MAP3K7CL -- TAB3
# MBNL3 -- MBNL1
# MBNL3 -- NXF1
# MBNL3 -- MOV10
# MBNL3 -- SHMT2
# MBNL3 -- DAB1
# MBNL3 -- SRPK1
# MCM9 -- THBS3
# MCM9 -- FAF2
# MCM9 -- MCM8
# MCM9 -- PLAUR
# MCM9 -- MCMBP
# MCM9 -- CAND1
# MDFIC -- SOCS4
# MDFIC -- RPS6KA5
# MDFIC -- CSNK2A1
# MDFIC -- CDK9
# MDFIC -- MDFIC
# MDFIC -- CCNT1
# MEGF6 -- GFI1B
# MEGF6 -- ATN1
# MEGF6 -- CRKL
# MEGF6 -- CACNA1A
# MEGF6 -- ATXN7
# MEGF6 -- EGFR
# METTL15 -- UBR2
# METTL15 -- LIPT1
# METTL15 -- BSG
# METTL15 -- MVB12B
# METTL15 -- TRIP13
# METTL15 -- CUL3
# MIEF2 -- AGTRAP
# MIEF2 -- DNM1L
# MIEF2 -- UBQLN4
# MIEF2 -- UBQLN1
# MIEF2 -- RABAC1
# MIEF2 -- PSMF1
# MRPS17 -- VPS16
# MRPS17 -- THOC1
# MRPS17 -- ECSIT
# MRPS17 -- MED4
# MRPS17 -- RNF2
# MRPS17 -- ICT1
# MSH5 -- SGTB
# MSH5 -- XRCC5
# MSH5 -- XPO1
# MSH5 -- ABL1
# MSH5 -- GPS2
# MSH5 -- MSH4
# MTG1 -- ISLR
# MTG1 -- DOCK8
# MTG1 -- APP
# MTG1 -- PRNP
# MTG1 -- ICT1
# MTG1 -- STRN4
# MYO1G -- THOC5
# MYO1G -- RPL10
# MYO1G -- SVIL
# MYO1G -- TFRC
# MYO1G -- RALA
# MYO1G -- SRGAP2
# NAGPA -- AP2M1
# NAGPA -- SLAMF7
# NAGPA -- ZHX2
# NAGPA -- DEGS1
# NAGPA -- AP2A1
# NAGPA -- EPS15
# NBPF22P -- PARVG
# NBPF22P -- ENKD1
# NBPF22P -- LMO3
# NBPF22P -- RGP1
# NBPF22P -- SMARCE1
# NBPF22P -- AQP1
# NDUFAF7 -- OXLD1
# NDUFAF7 -- RD3
# NDUFAF7 -- FNTB
# NDUFAF7 -- ST3GAL5
# NDUFAF7 -- NDUFA10
# NDUFAF7 -- APP
# NEIL2 -- EP300
# NEIL2 -- TRIM27
# NEIL2 -- REL
# NEIL2 -- MEOX1
# NEIL2 -- ELAVL1
# NEIL2 -- KEAP1
# NEK3 -- CDK13
# NEK3 -- VSIG4
# NEK3 -- CDCA8
# NEK3 -- BPGM
# NEK3 -- NMNAT1
# NEK3 -- HDAC6
# NFXL1 -- FOXL1
# NFXL1 -- WDFY2
# NFXL1 -- RNF2
# NFXL1 -- CLINT1
# NFXL1 -- ILF3
# NFXL1 -- SARM1
# NLRP4 -- SH3BP1
# NLRP4 -- SUGT1
# NLRP4 -- HSP90AA1
# NLRP4 -- DTX4
# NLRP4 -- TBK1
# NLRP4 -- CHUK
# NMUR2 -- NOTCH2NL
# NMUR2 -- KRTAP13-1
# NMUR2 -- ADAMTSL4
# NMUR2 -- TRAF2
# NMUR2 -- TCF4
# NMUR2 -- NMU
# NNMT -- CRYZ
# NNMT -- ADK
# NNMT -- GLOD4
# NNMT -- BMF
# NNMT -- ATF6
# NNMT -- APP
# NOMO3 -- EWSR1
# NOMO3 -- TMEM25
# NOMO3 -- FBXO6
# NOMO3 -- LIG4
# NOMO3 -- UBQLN4
# NOMO3 -- RYK
# NR2C2AP -- FKBP2
# NR2C2AP -- SLC16A3
# NR2C2AP -- TCF4
# NR2C2AP -- REL
# NR2C2AP -- BAG3
# NR2C2AP -- NR2C2
# NREP -- ATM
# NREP -- MAGED1
# NREP -- ELAVL1
# NREP -- EEF1A1
# NREP -- KMT2B
# NREP -- IGSF21
# NUDT19 -- CEP19
# NUDT19 -- OXLD1
# NUDT19 -- SLC25A41
# NUDT19 -- PEX5
# NUDT19 -- NPC2
# NUDT19 -- SLC9A3R2
# NXF2 -- LUZP4
# NXF2 -- APP
# NXF2 -- NXF1
# NXF2 -- NUP62
# NXF2 -- NUP153
# NXF2 -- NUP214
# NXF5 -- CCT7
# NXF5 -- CCT3
# NXF5 -- CCT8
# NXF5 -- HSPA6
# NXF5 -- HSPA8
# NXF5 -- NXF1
# OBP2A -- TXNDC15
# OBP2A -- COL6A2
# OBP2A -- MOXD1
# OBP2A -- CLN5
# OBP2A -- LRP2
# OBP2A -- OBP2B
# ODF1 -- KRTAP12-2
# ODF1 -- MTUS2
# ODF1 -- CDK5R1
# ODF1 -- CDK5
# ODF1 -- TRIP6
# ODF1 -- SPAG4
# ONECUT1 -- NR0B2
# ONECUT1 -- NR3C1
# ONECUT1 -- FOXA2
# ONECUT1 -- FOXA1
# ONECUT1 -- KAT2B
# ONECUT1 -- CREBBP
# ORAOV1 -- ABCE1
# ORAOV1 -- MMS19
# ORAOV1 -- YAE1D1
# ORAOV1 -- MSH3
# ORAOV1 -- CAND1
# ORAOV1 -- ELAVL1
# OSBPL2 -- BAG6
# OSBPL2 -- SGTB
# OSBPL2 -- HNRNPD
# OSBPL2 -- APBB2
# OSBPL2 -- VAPB
# OSBPL2 -- ELAVL1
# OXSM -- DHRS4
# OXSM -- NDUFAB1
# OXSM -- SOX2
# OXSM -- ATF6B
# OXSM -- GTF2B
# OXSM -- APP
# PANX1 -- FBXO7
# PANX1 -- CDC37
# PANX1 -- BAG3
# PANX1 -- TMEM17
# PANX1 -- C4orf3
# PANX1 -- GNAS
# PCDHGC3 -- NTRK1
# PCDHGC3 -- C2orf48
# PCDHGC3 -- CEACAM21
# PCDHGC3 -- MFSD3
# PCDHGC3 -- HGD
# PCDHGC3 -- APP
# PCYT1B -- PAXIP1
# PCYT1B -- APP
# PCYT1B -- KIAA0368
# PCYT1B -- ACTA1
# PCYT1B -- ACTA2
# PCYT1B -- ACTB
# PDXP -- STK11
# PDXP -- NTRK1
# PDXP -- NXF1
# PDXP -- MOV10
# PDXP -- ARRB1
# PDXP -- MED23
# PFKFB1 -- PFKFB1
# PFKFB1 -- APP
# PFKFB1 -- PRKACA
# PFKFB1 -- AKT1
# PFKFB1 -- PRKCA
# PFKFB1 -- MAPK3
# PHF23 -- FOXK2
# PHF23 -- STK11
# PHF23 -- ERBB2
# PHF23 -- LRSAM1
# PHF23 -- HCCS
# PHF23 -- PRSS23
# PIGQ -- TNFSF13B
# PIGQ -- SMAD1
# PIGQ -- PIGA
# PIGQ -- PIGC
# PIGQ -- PIGH
# PIGQ -- PIGP
# PIH1D3 -- KIF13A
# PIH1D3 -- CCAR1
# PIH1D3 -- CDKL3
# PIH1D3 -- KAT5
# PIH1D3 -- BTAF1
# PIH1D3 -- P2RX4
# PLCZ1 -- HBD
# PLCZ1 -- HAL
# PLCZ1 -- SERPINA12
# PLCZ1 -- SEMG1
# PLCZ1 -- CST6
# PLCZ1 -- KLK7
# PLEKHA4 -- PRKAA1
# PLEKHA4 -- CCNG1
# PLEKHA4 -- SETDB1
# PLEKHA4 -- LRIF1
# PLEKHA4 -- KAT5
# PLEKHA4 -- EEF1G
# PLEKHA6 -- XPO1
# PLEKHA6 -- NTRK1
# PLEKHA6 -- MYBPHL
# PLEKHA6 -- CFTR
# PLEKHA6 -- APOE
# PLEKHA6 -- PLEKHA5
# PLSCR3 -- CATSPER1
# PLSCR3 -- STK16
# PLSCR3 -- ALG2
# PLSCR3 -- PRKCD
# PLSCR3 -- TRIP13
# PLSCR3 -- PLSCR1
# PLXNB3 -- MAGI3
# PLXNB3 -- BTBD3
# PLXNB3 -- MAGI2
# PLXNB3 -- SPOCK2
# PLXNB3 -- CUL7
# PLXNB3 -- ARHGEF11
# PRAP1 -- IGHA1
# PRAP1 -- CD48
# PRAP1 -- LACRT
# PRAP1 -- UBQLN1
# PRAP1 -- SGTA
# PRAP1 -- GRB2
# PRDM10 -- FOXK2
# PRDM10 -- CASQ2
# PRDM10 -- TMEFF1
# PRDM10 -- REL
# PRDM10 -- CUL1
# PRDM10 -- BAP1
# PRKX -- XPO1
# PRKX -- PRKAR2B
# PRKX -- HSP90AA1
# PRKX -- NEDD4L
# PRKX -- NEDD4
# PRKX -- PRKAR1A
# PRR16 -- ABI2
# PRR16 -- PPP1CC
# PRR16 -- APP
# PRR16 -- PPP1CA
# PRR16 -- NEDD4L
# PRR16 -- NEDD4
# PRSS21 -- MBOAT1
# PRSS21 -- RTEL1
# PRSS21 -- NCSTN
# PRSS21 -- TUBG1
# PRSS21 -- LGALS3BP
# PRSS21 -- FBXO6
# PTPN7 -- MAPK14
# PTPN7 -- CCDC57
# PTPN7 -- GMCL1
# PTPN7 -- APP
# PTPN7 -- MAPK3
# PTPN7 -- MAPK1
# PTPRR -- CEP290
# PTPRR -- NTRK1
# PTPRR -- MAPK14
# PTPRR -- MAPK7
# PTPRR -- MAPK3
# PTPRR -- MAPK1
# PTTG1IP -- STX7
# PTTG1IP -- LDLRAD1
# PTTG1IP -- CLEC7A
# PTTG1IP -- TP53
# PTTG1IP -- RAB4A
# PTTG1IP -- PTTG1
# PUS7L -- STAT5B
# PUS7L -- GAK
# PUS7L -- TRIM41
# PUS7L -- TRIM27
# PUS7L -- UBC
# PUS7L -- APP
# QRICH2 -- PANK2
# QRICH2 -- NUP98
# QRICH2 -- GAPDH
# QRICH2 -- MPDU1
# QRICH2 -- SNAI1
# QRICH2 -- SSSCA1
# RAB27B -- SYTL5
# RAB27B -- DHPS
# RAB27B -- MLPH
# RAB27B -- SYTL2
# RAB27B -- SYTL1
# RAB27B -- SYTL4
# RAB39A -- KLK8
# RAB39A -- BLZF1
# RAB39A -- GOLGA2
# RAB39A -- UBL4A
# RAB39A -- APP
# RAB39A -- RAB3GAP1
# RAC3 -- RHOC
# RAC3 -- FBXL19
# RAC3 -- ESR1
# RAC3 -- ARHGDIA
# RAC3 -- ARHGDIB
# RAC3 -- CIB1
# RALGAPA1 -- CEP63
# RALGAPA1 -- AP2M1
# RALGAPA1 -- GFOD1
# RALGAPA1 -- SLMAP
# RALGAPA1 -- TERF2
# RALGAPA1 -- TERF1
# RASA3 -- GAPVD1
# RASA3 -- ARHGAP19
# RASA3 -- SPTB
# RASA3 -- APP
# RASA3 -- GNB2L1
# RASA3 -- HCK
# RASL11B -- BAG3
# RASL11B -- APP
# RASL11B -- LNX1
# RASL11B -- NEDD4L
# RASL11B -- NEDD4
# RASL11B -- EWSR1
# RBP7 -- DOK4
# RBP7 -- DAPP1
# RBP7 -- APPL2
# RBP7 -- SOCS4
# RBP7 -- PIK3R3
# RBP7 -- HSH2D
# RCOR2 -- CTBP1
# RCOR2 -- HMG20B
# RCOR2 -- SUMO2
# RCOR2 -- HDAC11
# RCOR2 -- HDAC1
# RCOR2 -- HDAC2
# REM1 -- SULT1A4
# REM1 -- WBSCR22
# REM1 -- YWHAE
# REM1 -- YWHAH
# REM1 -- YWHAZ
# REM1 -- YWHAQ
# RHEBL1 -- APPL1
# RHEBL1 -- FHL3
# RHEBL1 -- MTOR
# RHEBL1 -- PRKAB2
# RHEBL1 -- TRAF2
# RHEBL1 -- TXNL4A
# RHOBTB1 -- MYC
# RHOBTB1 -- HSP90AA1
# RHOBTB1 -- CUL5
# RHOBTB1 -- COPS6
# RHOBTB1 -- COPS5
# RHOBTB1 -- CUL3
# RILPL2 -- KRAS
# RILPL2 -- MOV10
# RILPL2 -- CAND1
# RILPL2 -- TUBB3
# RILPL2 -- HEXDC
# RILPL2 -- RILPL2
# RIPPLY1 -- THAP1
# RIPPLY1 -- HDAC7
# RIPPLY1 -- RBPMS
# RIPPLY1 -- TRAF2
# RIPPLY1 -- REL
# RIPPLY1 -- MDFI
# ROR1 -- TMEM17
# ROR1 -- TBC1D4
# ROR1 -- TBC1D1
# ROR1 -- MORC3
# ROR1 -- TRIM21
# ROR1 -- APP
# RP9P -- RP9P
# RP9P -- SREK1IP1
# RP9P -- THAP1
# RP9P -- PRR13
# RP9P -- RBM39
# RP9P -- SDCBP
# RPL41 -- NUPR1
# RPL41 -- SRPK2
# RPL41 -- APP
# RPL41 -- PRNP
# RPL41 -- MAPK14
# RPL41 -- IKBKG
# RPS26P54 -- CAND1
# RPS26P54 -- COPS5
# RPS26P54 -- CUL1
# RPS26P54 -- CUL5
# RPS26P54 -- CUL4B
# RPS26P54 -- CUL3
# RWDD3 -- VHL
# RWDD3 -- NXF1
# RWDD3 -- HIF1A
# RWDD3 -- NFKBIA
# RWDD3 -- UBE2I
# RWDD3 -- SUMO1
# RYR3 -- BMI1
# RYR3 -- HNF1A
# RYR3 -- CFTR
# RYR3 -- CUL1
# RYR3 -- FKBP1A
# RYR3 -- RYR2
# SAPCD1 -- CTNNB1
# SAPCD1 -- RANGRF
# SAPCD1 -- ARHGAP23
# SAPCD1 -- ARHGAP21
# SAPCD1 -- CTNNA2
# SAPCD1 -- LNX1
# SAT2 -- SAT2
# SAT2 -- KAT2B
# SAT2 -- VHL
# SAT2 -- TCEB1
# SAT2 -- HIF1A
# SAT2 -- SAT1
# SBK1 -- SRPK2
# SBK1 -- PPM1G
# SBK1 -- FCHSD1
# SBK1 -- TRIP10
# SBK1 -- PACSIN3
# SBK1 -- PACSIN2
# SCTR -- CYFIP1
# SCTR -- DNAL4
# SCTR -- SNTA1
# SCTR -- CPAMD8
# SCTR -- ADCYAP1
# SCTR -- SCT
# SDK1 -- LGALS8
# SDK1 -- LGALS3
# SDK1 -- PRPF40A
# SDK1 -- MYC
# SDK1 -- UBC
# SDK1 -- LNX1
# SDPR -- FAN1
# SDPR -- A1CF
# SDPR -- SDPR
# SDPR -- NPM1
# SDPR -- PLEKHF2
# SDPR -- NUDT18
# SEC14L4 -- INCA1
# SEC14L4 -- BMF
# SEC14L4 -- USHBP1
# SEC14L4 -- TCF4
# SEC14L4 -- REL
# SEC14L4 -- ELAVL1
# SELO -- HERC2
# SELO -- PGPEP1
# SELO -- MRM1
# SELO -- C4orf29
# SELO -- C1QTNF2
# SELO -- METTL20
# SELV -- PRR20A
# SELV -- ZMYND19
# SELV -- ZMIZ2
# SELV -- APPBP2
# SELV -- GOLGA2
# SELV -- PAXIP1
# SEMA4D -- CRK
# SEMA4D -- ELAVL1
# SEMA4D -- PLXNB1
# SEMA4D -- SEMA4D
# SEMA4D -- PTPRC
# SEMA4D -- CD72
# SGK223 -- CRKL
# SGK223 -- YWHAE
# SGK223 -- HSP90AA1
# SGK223 -- UBE3A
# SGK223 -- PSAP
# SGK223 -- CHGB
# SGK3 -- NEDD4L
# SGK3 -- HSP90AA1
# SGK3 -- APP
# SGK3 -- ITCH
# SGK3 -- ESR1
# SGK3 -- GSK3B
# SH2D3C -- EGFR
# SH2D3C -- LYN
# SH2D3C -- NEDD9
# SH2D3C -- BCAR1
# SH2D3C -- SNCAIP
# SH2D3C -- EFS
# SH3D19 -- NPHP1
# SH3D19 -- SH3KBP1
# SH3D19 -- ELAVL1
# SH3D19 -- CDC42
# SH3D19 -- GRB2
# SH3D19 -- SH3YL1
# SLC16A3 -- TERF2IP
# SLC16A3 -- TSNAX
# SLC16A3 -- DIAPH1
# SLC16A3 -- FAM9B
# SLC16A3 -- NR2C2AP
# SLC16A3 -- BANP
# SLC25A30 -- LOC554223
# SLC25A30 -- DNAJB11
# SLC25A30 -- SDF4
# SLC25A30 -- BTN2A1
# SLC25A30 -- BSG
# SLC25A30 -- C4BPB
# SLC25A48 -- KRTAP10-3
# SLC25A48 -- KRTAP10-7
# SLC25A48 -- UBASH3B
# SLC25A48 -- MID2
# SLC25A48 -- PNMA1
# SLC25A48 -- TRAF1
# SLC41A3 -- CREB3
# SLC41A3 -- ZACN
# SLC41A3 -- PDZD3
# SLC41A3 -- REL
# SLC41A3 -- APP
# SLC41A3 -- MAPK6
# SLN -- SYNE4
# SLN -- CCDC155
# SLN -- TMEM79
# SLN -- ATP2A2
# SLN -- PLN
# SLN -- ATP2A1
# SLX1A -- GRB2
# SLX1A -- EME1
# SLX1A -- MUS81
# SLX1A -- ERCC1
# SLX1A -- ERCC4
# SLX1A -- SLX4
# SMCO4 -- KRTAP10-3
# SMCO4 -- KRTAP10-7
# SMCO4 -- SYNE4
# SMCO4 -- CCDC155
# SMCO4 -- KRT40
# SMCO4 -- BNIP3L
# SNX22 -- CSNK1E
# SNX22 -- CSNK1A1
# SNX22 -- B3GALT2
# SNX22 -- POT1
# SNX22 -- TERF2
# SNX22 -- DVL3
# SNX33 -- MCM2
# SNX33 -- GLI1
# SNX33 -- NAF1
# SNX33 -- FASLG
# SNX33 -- SNX9
# SNX33 -- SNX33
# SOCS7 -- SEPT6
# SOCS7 -- STAT5A
# SOCS7 -- STAT3
# SOCS7 -- SORBS3
# SOCS7 -- CUL5
# SOCS7 -- NCK1
# SP140L -- LDHD
# SP140L -- TM9SF4
# SP140L -- RAPGEF2
# SP140L -- MAGEA1
# SP140L -- APP
# SP140L -- NEDD4
# SRFBP1 -- C10orf12
# SRFBP1 -- FBXW5
# SRFBP1 -- DDX10
# SRFBP1 -- BYSL
# SRFBP1 -- FBL
# SRFBP1 -- SRF
# STAP1 -- CAPZB
# STAP1 -- CAPZA2
# STAP1 -- SULT1A1
# STAP1 -- CD2AP
# STAP1 -- FAM134C
# STAP1 -- SH3KBP1
# STARD7 -- PIGM
# STARD7 -- TLE3
# STARD7 -- TLE1
# STARD7 -- KIAA0907
# STARD7 -- NAT2
# STARD7 -- BAG3
# STARD9 -- MCL1
# STARD9 -- ABCE1
# STARD9 -- PPP1CC
# STARD9 -- SVIL
# STARD9 -- HERPUD1
# STARD9 -- CDK5RAP2
# STRADB -- ELAVL1
# STRADB -- GRB2
# STRADB -- STK11
# STRADB -- XIAP
# STRADB -- TRAF6
# STRADB -- MAP3K7
# STYXL1 -- PSPH
# STYXL1 -- EHD4
# STYXL1 -- ATXN10
# STYXL1 -- RPS29
# STYXL1 -- SMC1A
# STYXL1 -- AES
# SYNGR2 -- FATE1
# SYNGR2 -- EDNRA
# SYNGR2 -- GPR52
# SYNGR2 -- SYNE4
# SYNGR2 -- SCARA3
# SYNGR2 -- ATP4A
# SYTL5 -- CEP70
# SYTL5 -- WAC
# SYTL5 -- RAB27B
# SYTL5 -- RAB6A
# SYTL5 -- RAB3A
# SYTL5 -- RAB27A
# TANC2 -- NR2C2
# TANC2 -- XPO1
# TANC2 -- PPP1CA
# TANC2 -- PPP1CC
# TANC2 -- YWHAB
# TANC2 -- LATS2
# TBC1D10C -- NOTCH2NL
# TBC1D10C -- KRTAP13-1
# TBC1D10C -- KLHL12
# TBC1D10C -- KRTAP5-9
# TBC1D10C -- HOXA1
# TBC1D10C -- APP
# TBRG1 -- ACTR5
# TBRG1 -- INO80E
# TBRG1 -- CCDC136
# TBRG1 -- RALBP1
# TBRG1 -- RUNDC3A
# TBRG1 -- MDM2
# TBX2 -- TEAD2
# TBX2 -- PML
# TBX2 -- SOX2
# TBX2 -- EGR1
# TBX2 -- LZTR1
# TBX2 -- CEBPE
# TESC -- WBP11
# TESC -- SLC9A1
# TESC -- DYNLT3
# TESC -- CCDC91
# TESC -- RAI1
# TESC -- HMG20A
# TEX37 -- DAZAP2
# TEX37 -- KPNA3
# TEX37 -- APP
# TEX37 -- RBPMS
# TEX37 -- MAGEA11
# TEX37 -- TRIP13
# THNSL1 -- FOXD4L6
# THNSL1 -- TMEFF1
# THNSL1 -- CCDC74B
# THNSL1 -- UTP11L
# THNSL1 -- ICT1
# THNSL1 -- UIMC1
# TM9SF1 -- CHMP4B
# TM9SF1 -- RNASEH1
# TM9SF1 -- TCOF1
# TM9SF1 -- P2RX7
# TM9SF1 -- ATP6V1B1
# TM9SF1 -- MME
# TMED7 -- PA2G4
# TMED7 -- GABRE
# TMED7 -- TMEM30A
# TMED7 -- TMED10
# TMED7 -- TMPRSS3
# TMED7 -- ELAVL1
# TMEM120B -- TCTN3
# TMEM120B -- TCTN2
# TMEM120B -- CHRNA9
# TMEM120B -- POMK
# TMEM120B -- SLC39A4
# TMEM120B -- CCNDBP1
# TMEM159 -- FAF2
# TMEM159 -- ZNF391
# TMEM159 -- ADCK3
# TMEM159 -- CACFD1
# TMEM159 -- GAD2
# TMEM159 -- ELAVL1
# TMEM179B -- HTR3C
# TMEM179B -- FAM189A2
# TMEM179B -- GPR52
# TMEM179B -- LGALS3
# TMEM179B -- HNRNPR
# TMEM179B -- HNRNPUL1
# TMEM2 -- TMEM17
# TMEM2 -- NAAA
# TMEM2 -- SIAE
# TMEM2 -- PTCH1
# TMEM2 -- FBXO6
# TMEM2 -- ELAVL1
# TMEM219 -- PON2
# TMEM219 -- ZACN
# TMEM219 -- BTNL8
# TMEM219 -- MCOLN3
# TMEM219 -- ITM2B
# TMEM219 -- HLA-DQA1
# TMEM39B -- CHRNA9
# TMEM39B -- ISLR
# TMEM39B -- POMK
# TMEM39B -- NRG1
# TMEM39B -- IL13RA1
# TMEM39B -- UBC
# TMEM41B -- PPP2CB
# TMEM41B -- TCTN3
# TMEM41B -- APOB
# TMEM41B -- DPYS
# TMEM41B -- BMI1
# TMEM41B -- ELAVL1
# TMEM54 -- CREB3
# TMEM54 -- RBBP8
# TMEM54 -- PEX19
# TMEM54 -- HDAC1
# TMEM54 -- RARA
# TMEM54 -- CDK2
# TMEM97 -- GUK1
# TMEM97 -- STXBP3
# TMEM97 -- HLA-DRA
# TMEM97 -- EGFR
# TMEM97 -- APP
# TMEM97 -- ELAVL1
# TNFRSF10D -- TNFSF10
# TNFRSF10D -- TRIM28
# TNFRSF10D -- SF3B3
# TNFRSF10D -- PFAS
# TNFRSF10D -- MYH10
# TNFRSF10D -- LRPPRC
# TNFRSF17 -- TRAF6
# TNFRSF17 -- TRAF5
# TNFRSF17 -- TRAF3
# TNFRSF17 -- TRAF2
# TNFRSF17 -- TRAF1
# TNFRSF17 -- TNFSF13B
# TPGS2 -- TTLL1
# TPGS2 -- C11orf49
# TPGS2 -- ZDHHC17
# TPGS2 -- NXF1
# TPGS2 -- MOV10
# TPGS2 -- EWSR1
# TPPP -- C2orf27B
# TPPP -- HIST1H1A
# TPPP -- CDK11B
# TPPP -- APP
# TPPP -- SNCA
# TPPP -- HDAC6
# TRIM58 -- UBE2D3
# TRIM58 -- TRIM58
# TRIM58 -- DYNC1LI2
# TRIM58 -- DYNC2LI1
# TRIM58 -- DYNC1I1
# TRIM58 -- DYNC1H1
# TRIM6 -- IKBKE
# TRIM6 -- TRIM5
# TRIM6 -- MYC
# TRIM6 -- TRIM28
# TRIM6 -- TRIM23
# TRIM6 -- TRIM6
# TRMT11 -- PLAUR
# TRMT11 -- AKR7A3
# TRMT11 -- TP73
# TRMT11 -- TP63
# TRMT11 -- TP53
# TRMT11 -- WDR48
# TTC39C -- HSPB1
# TTC39C -- NXF1
# TTC39C -- MOV10
# TTC39C -- SHMT2
# TTC39C -- ACAT2
# TTC39C -- THOP1
# TULP2 -- MTUS2
# TULP2 -- BRCA1
# TULP2 -- BARD1
# TULP2 -- ELAVL1
# TULP2 -- MEOX2
# TULP2 -- EWSR1
# TYSND1 -- XPO1
# TYSND1 -- TYSND1
# TYSND1 -- TH
# TYSND1 -- ACOX1
# TYSND1 -- PEX5
# TYSND1 -- JOSD2
# UAP1L1 -- WDR1
# UAP1L1 -- OAT
# UAP1L1 -- SDHB
# UAP1L1 -- RAB11B
# UAP1L1 -- PCBD1
# UAP1L1 -- AFMID
# UBE3D -- CPSF3
# UBE3D -- FKBP6
# UBE3D -- MEMO1
# UBE3D -- CCNB1
# UBE3D -- UBE3D
# UBE3D -- UBE2C
# UCK2 -- UPRT
# UCK2 -- CCDC8
# UCK2 -- EGFR
# UCK2 -- FBXO6
# UCK2 -- UPP1
# UCK2 -- UBC
# UCKL1 -- BCS1L
# UCKL1 -- KAT5
# UCKL1 -- SKAP1
# UCKL1 -- MPPED1
# UCKL1 -- UPRT
# UCKL1 -- CIAO1
# UEVLD -- UBC
# UEVLD -- LRSAM1
# UEVLD -- DTX3
# UEVLD -- TRAF6
# UEVLD -- RNF114
# UEVLD -- RNF4
# UPRT -- MPPED1
# UPRT -- UCKL1
# UPRT -- IRF2BP2
# UPRT -- UCK2
# UPRT -- UCK1
# UPRT -- PYROXD1
# UTY -- KIF1C
# UTY -- PCNA
# UTY -- PRDX2
# UTY -- NCOA6
# UTY -- TLE2
# UTY -- TLE1
# WBP2NL -- OTUD4
# WBP2NL -- INO80C
# WBP2NL -- PCGF6
# WBP2NL -- ACTR5
# WBP2NL -- MGA
# WBP2NL -- FMR1
# WDR47 -- TCF4
# WDR47 -- CDK11A
# WDR47 -- C1orf186
# WDR47 -- IDS
# WDR47 -- TCL1A
# WDR47 -- TCEA2
# WDR7 -- NTRK1
# WDR7 -- ATP6V1B1
# WDR7 -- ROGDI
# WDR7 -- FRMD6
# WDR7 -- RAB3GAP1
# WDR7 -- DMXL2
# XRCC6BP1 -- HLA-E
# XRCC6BP1 -- NUP35
# XRCC6BP1 -- CSPP1
# XRCC6BP1 -- TRIP6
# XRCC6BP1 -- AP2B1
# XRCC6BP1 -- XRCC6
# XXYLT1 -- FAM63B
# XXYLT1 -- NXF1
# XXYLT1 -- MOV10
# XXYLT1 -- SHMT2
# XXYLT1 -- CUL4A
# XXYLT1 -- ELAVL1
# YBX2 -- RPS2
# YBX2 -- NIFK
# YBX2 -- HIST1H1A
# YBX2 -- HDAC11
# YBX2 -- ICAM1
# YBX2 -- IGSF8
# YIPF4 -- TMEM63B
# YIPF4 -- UNK
# YIPF4 -- FAM134C
# YIPF4 -- RNF185
# YIPF4 -- FATE1
# YIPF4 -- YIPF3
# ZBTB4 -- ZBTB17
# ZBTB4 -- CBFA2T3
# ZBTB4 -- TP63
# ZBTB4 -- HIPK2
# ZBTB4 -- SIN3B
# ZBTB4 -- SIN3A
# ZBTB8B -- PPIP5K1
# ZBTB8B -- LSM7
# ZBTB8B -- PPIP5K2
# ZBTB8B -- CPSF6
# ZBTB8B -- ILF2
# ZBTB8B -- KIF5B
# ZC3H7A -- XPO1
# ZC3H7A -- NTRK1
# ZC3H7A -- BIRC7
# ZC3H7A -- BMI1
# ZC3H7A -- STK3
# ZC3H7A -- PAK1
# ZFP1 -- IPO8
# ZFP1 -- SERTAD4
# ZFP1 -- SESN3
# ZFP1 -- AKR1C2
# ZFP1 -- CBX5
# ZFP1 -- HDAC2
# ZFYVE28 -- PRNP
# ZFYVE28 -- EGFR
# ZFYVE28 -- RAB7A
# ZFYVE28 -- RAB4A
# ZFYVE28 -- RAB5A
# ZFYVE28 -- EGF
# ZNF135 -- GADD45A
# ZNF135 -- ANXA7
# ZNF135 -- RCC1
# ZNF135 -- CDKN1A
# ZNF135 -- RAP1B
# ZNF135 -- GSK3B
# ZNF136 -- KRTAP10-3
# ZNF136 -- CCNDBP1
# ZNF136 -- MTUS2
# ZNF136 -- CEP70
# ZNF136 -- PPP2R2B
# ZNF136 -- MDFI
# ZNF142 -- MCM2
# ZNF142 -- PTTG1
# ZNF142 -- MUS81
# ZNF142 -- NXF1
# ZNF142 -- CHMP5
# ZNF142 -- MAPK14
# ZNF2 -- CCND3
# ZNF2 -- KRTAP10-7
# ZNF2 -- TSGA10
# ZNF2 -- PRMT5
# ZNF2 -- TRIM28
# ZNF2 -- APP
# ZNF202 -- KRTAP10-3
# ZNF202 -- KRT40
# ZNF202 -- SNX2
# ZNF202 -- MZF1
# ZNF202 -- PCBD1
# ZNF202 -- ZNF473
# ZNF227 -- CEP70
# ZNF227 -- UMPS
# ZNF227 -- CBX5
# ZNF227 -- RPS6KA6
# ZNF227 -- GSK3B
# ZNF227 -- CSNK1E
# ZNF230 -- KRT40
# ZNF230 -- FSD2
# ZNF230 -- CCDC136
# ZNF230 -- CCNDBP1
# ZNF230 -- MDFI
# ZNF230 -- NDEL1
# ZNF251 -- MX1
# ZNF251 -- SMAD1
# ZNF251 -- PAXIP1
# ZNF251 -- MDC1
# ZNF251 -- FEZ2
# ZNF251 -- FEZ1
# ZNF26 -- KRTAP10-3
# ZNF26 -- KRTAP10-7
# ZNF26 -- KRT40
# ZNF26 -- TRIM41
# ZNF26 -- TRIM39
# ZNF26 -- TP53BP2
# ZNF273 -- FAM46A
# ZNF273 -- HDAC1
# ZNF273 -- ZNF707
# ZNF273 -- KRTAP10-5
# ZNF273 -- CA14
# ZNF273 -- SP8
# ZNF384 -- TRIP6
# ZNF384 -- TUBA3C
# ZNF384 -- SOX2
# ZNF384 -- OPTN
# ZNF384 -- HOXC9
# ZNF384 -- CEBPE
# ZNF394 -- USP7
# ZNF394 -- ZSCAN20
# ZNF394 -- ZNF397
# ZNF394 -- ZSCAN32
# ZNF394 -- CCNDBP1
# ZNF394 -- CLK2
# ZNF395 -- BTRC
# ZNF395 -- FBXW11
# ZNF395 -- WASL
# ZNF395 -- ELAVL1
# ZNF395 -- HDAC1
# ZNF395 -- SAP30
# ZNF578 -- KRTAP10-3
# ZNF578 -- KRTAP10-8
# ZNF578 -- KRTAP10-9
# ZNF578 -- KRTAP10-7
# ZNF578 -- CEP70
# ZNF578 -- MDFI
# ZNF580 -- ARHGEF6
# ZNF580 -- SH3GL2
# ZNF580 -- XBP1
# ZNF580 -- PAX9
# ZNF580 -- RAD54B
# ZNF580 -- TSC22D4
# ZNF625 -- KRTAP10-3
# ZNF625 -- KRTAP10-9
# ZNF625 -- KRTAP10-7
# ZNF625 -- KRTAP10-4
# ZNF625 -- KRT40
# ZNF625 -- CBX5
# ZNF629 -- IPO8
# ZNF629 -- HIST1H2BG
# ZNF629 -- NTRK1
# ZNF629 -- FBL
# ZNF629 -- RPSA
# ZNF629 -- RPL14
# ZNF645 -- SRSF10
# ZNF645 -- SERTAD4
# ZNF645 -- ZC3H13
# ZNF645 -- WTAP
# ZNF645 -- PPP2R2D
# ZNF645 -- KIAA1429
# ZNF71 -- SSX2IP
# ZNF71 -- RIN3
# ZNF71 -- KDM1A
# ZNF71 -- PLK1
# ZNF71 -- PRKCZ
# ZNF71 -- CSNK2B
# ZNF747 -- APP
# ZNF747 -- ZNF707
# ZNF747 -- APPBP2
# ZNF747 -- CBX5
# ZNF747 -- ELAVL1
# ZNF747 -- SUFU
# ZNF775 -- ZAK
# ZNF775 -- MAPK6
# ZNF775 -- FES
# ZNF775 -- RPS6KA5
# ZNF775 -- OSGEP
# ZNF775 -- PPP2CB
# ZNF8 -- HIST1H2BG
# ZNF8 -- NXF1
# ZNF8 -- SHMT2
# ZNF8 -- CBX5
# ZNF8 -- CBX3
# ZNF8 -- SMARCAD1
# ZNF800 -- CNTROB
# ZNF800 -- VPS16
# ZNF800 -- TM9SF4
# ZNF800 -- PRR11
# ZNF800 -- NPM1
# ZNF800 -- ELAVL1
# ZNRF2P1 -- KRTAP10-3
# ZNRF2P1 -- KRT40
# ZNRF2P1 -- USHBP1
# ZNRF2P1 -- CCNDBP1
# ZNRF2P1 -- KRT31
# ZNRF2P1 -- HNRNPK
# ZUFSP -- TCEAL1
# ZUFSP -- SHMT2
# ZUFSP -- RPS21
# ZUFSP -- PRMT5
# ZUFSP -- CLN8
# ZUFSP -- SHCBP1

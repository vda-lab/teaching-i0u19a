# %%
# %load_ext sql

# %%
# %sql sqlite:///omop.sqlite
# Out:
# 'Connected: None@omop.sqlite'

# %%
# %sql select * from people limit 2;
# Out:
# (sqlite3.OperationalError) no such table: people [SQL: 'select * from people limit 2;']
